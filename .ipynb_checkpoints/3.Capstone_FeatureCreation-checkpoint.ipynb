# %% [markdown]
# # **Advanced Data Science Capstone: Automated Image Processing for Breast Tumor Biopsies**
#
# ## **Feature Creation Notebook**
# Author: Fernando M. Delgado Chaves

# %% [markdown]
# ## 2. Results
#
# ### 2.3 Feature Engineering
#
# Already in the initial data exploration, the correlation between features was observed. Let's compute it again for our cleansed dataset.

# %%
import pandas as pd

data = pd.read_csv('cleansed_data.csv')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M     0.643144      0.272574        0.615783   0.501591
# 1         M     0.601496      0.390260        0.595743   0.449417
# 2         M     0.629893      0.156578        0.630986   0.489290
# 3         M     0.258839      0.202570        0.267984   0.141506
# 4         M     0.533343      0.347311        0.523875   0.380276
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.289880          0.181768        0.203608             0.348757
# 1         0.514309          0.431017        0.462512             0.635686
# 2         0.430351          0.347893        0.463918             0.518390
# 3         0.678613          0.461996        0.369728             0.402038
# 4         0.379164          0.274891        0.264058             0.367793
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = data.drop(['diagnosis'], axis=1).corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# From here we learn that there are groups of correlated features:
# - *compactness mean, smoothness mean concavity mean* and *concave points mean*. I took *concave points mean*
# - *radius se, perimeter se* and *area se*. I took *area_se*
# - *radius worst, perimeter worst* and *area worst*. I took *area_worst*
# - *compactness worst, concavity worst* and *concave points worst*. I took *concave points worst*
# - *compactness se, concavity se* and *concave points se*. I took *concave points se*
# - *texture mean* and *texture worst*. I took *texture worst*
# - *area worst*, *radius mean*, *perimeter mean* and *area mean*. I took *area mean*

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
droplist = ['compactness_mean', 'concavity_mean', 'radius_se', 'perimeter_se',
           'radius_worst', 'perimeter_worst', 'area_worst', 'compactness_worst', 
           'concavity_worst', 'compactness_se', 'concavity_se',
           'texture_mean','area_worst', 'radius_mean', 'perimeter_mean', 'concave points_worst']
data_filt = data.drop(droplist, axis=1)
data_filt.head()
# Out:
#   diagnosis  area_mean  smoothness_mean  concave points_mean  symmetry_mean  \
# 0         M   0.501591         0.289880             0.348757       0.379798
# 1         M   0.449417         0.514309             0.635686       0.509596
# 2         M   0.489290         0.430351             0.518390       0.378283
# 3         M   0.141506         0.678613             0.402038       0.518687
# 4         M   0.380276         0.379164             0.367793       0.370707
#
#    fractal_dimension_mean  texture_se   area_se  smoothness_se  \
# 0                0.141323    0.082589  0.125660       0.119387
# 1                0.211247    0.094303  0.162922       0.150831
# 2                0.186816    0.093065  0.163688       0.332359
# 3                0.551179    0.117132  0.038080       0.197063
# 4                0.157119    0.091275  0.087987       0.088418
#
#    concave points_se  symmetry_se  fractal_dimension_se  texture_worst  \
# ...

# %%
corr_matrix = data_filt.drop(['diagnosis'], axis=1).corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# The selected features are:

# %%
data_filt.columns
# Out:
# Index(['diagnosis', 'area_mean', 'smoothness_mean', 'concave points_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_se',
#        'smoothness_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'texture_worst', 'smoothness_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')
